# %%
import pandas as pd
import re
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
polizas1 = pd.read_csv("c1_POLIZAS.csv",index_col=False)
polizas2 = pd.read_csv("c2_POLIZAS.csv",index_col=False)
polizas3 = pd.read_csv("c3_POLIZAS.csv",index_col=False)
polizas4 = pd.read_csv("c4_POLIZAS.csv",index_col=False)
polizas5 = pd.read_csv("c5_POLIZAS.csv",index_col=False)
polizas6 = pd.read_csv("c6_POLIZAS.csv",index_col=False)
polizas7 = pd.read_csv("c7_POLIZAS.csv",index_col=False)
polizas8 = pd.read_csv("c8_POLIZAS.csv",index_col=False)
polizas9 = pd.read_csv("c9_POLIZAS.csv",index_col=False)

# %%
otros1=polizas1.loc[
   # polizas.POL_FechaAnulacion.notnull()
    # (polizas1.POL_MotivoAnulacion == 99)
     (polizas1.POL_DescripcionMotivo.notnull())
    & (polizas1.POL_DescripcionMotivo != "* Anulación automática"),
    [
       
        "POL_MotivoAnulacion", "POL_DescripcionMotivo",
    ],
]

otros2=polizas2.loc[
   # polizas.POL_FechaAnulacion.notnull()
     #(polizas2.POL_MotivoAnulacion == 99)
     (polizas2.POL_DescripcionMotivo.notnull())
    & (polizas2.POL_DescripcionMotivo != "* Anulación automática"),
    [
       
        "POL_MotivoAnulacion", "POL_DescripcionMotivo",
    ],
]
otros3=polizas3.loc[
   # polizas.POL_FechaAnulacion.notnull()
     # (polizas3.POL_MotivoAnulacion == 99)
     (polizas3.POL_DescripcionMotivo.notnull())
    & (polizas3.POL_DescripcionMotivo != "* Anulación automática"),
    [
       
       "POL_MotivoAnulacion", "POL_DescripcionMotivo",
    ],
]
otros4=polizas4.loc[
   # polizas.POL_FechaAnulacion.notnull()
    # (polizas4.POL_MotivoAnulacion == 99)
     (polizas4.POL_DescripcionMotivo.notnull())
    & (polizas4.POL_DescripcionMotivo != "* Anulación automática"),
    [
       
        "POL_MotivoAnulacion", "POL_DescripcionMotivo",
    ],
]
otros5=polizas5.loc[
   # polizas.POL_FechaAnulacion.notnull()
    # (polizas5.POL_MotivoAnulacion == 99)
     (polizas5.POL_DescripcionMotivo.notnull())
    & (polizas5.POL_DescripcionMotivo != "* Anulación automática"),
    [
       
        "POL_MotivoAnulacion", "POL_DescripcionMotivo",
    ],
]
otros6=polizas6.loc[
   # polizas.POL_FechaAnulacion.notnull()
     #(polizas6.POL_MotivoAnulacion == 99)
     (polizas6.POL_DescripcionMotivo.notnull())
    & (polizas6.POL_DescripcionMotivo != "* Anulación automática"),
    [
       
        "POL_MotivoAnulacion", "POL_DescripcionMotivo",
    ],
]
otros7=polizas7.loc[
   # polizas.POL_FechaAnulacion.notnull()
    # (polizas7.POL_MotivoAnulacion == 99)
     (polizas7.POL_DescripcionMotivo.notnull())
    & (polizas7.POL_DescripcionMotivo != "* Anulación automática"),
    [
       
        "POL_MotivoAnulacion", "POL_DescripcionMotivo",
    ],
]
otros8=polizas8.loc[
   # polizas.POL_FechaAnulacion.notnull()
     #(polizas8.POL_MotivoAnulacion == 99)
     (polizas8.POL_DescripcionMotivo.notnull())
    & (polizas8.POL_DescripcionMotivo != "* Anulación automática"),
    [
       
        "POL_MotivoAnulacion", "POL_DescripcionMotivo",
    ],
]
otros9=polizas9.loc[
   # polizas.POL_FechaAnulacion.notnull()
    # (polizas9.POL_MotivoAnulacion == 99)
     (polizas9.POL_DescripcionMotivo.notnull())
    & (polizas9.POL_DescripcionMotivo != "* Anulación automática"),
    [
       
        "POL_MotivoAnulacion", "POL_DescripcionMotivo",
    ],
]
print("c1", otros1.count)
print("c2",otros2.count)
# Out:
# c1 <bound method DataFrame.count of        POL_MotivoAnulacion            POL_DescripcionMotivo
# 100                   99.0         TOMADOR CAMBIA DE AGENTE
# 809                   99.0          desaparicion del riesgo
# 975                   99.0       RESCATE TOTAL DE LA POLIZA
# 1214                   5.0               pol. 8140800029032
# 1410                   6.0  Impago: NO RENUEVA (POR PRECIO)
# ...                    ...                              ...
# 26851                  6.0                           reale
# 26881                 99.0         A PETICIÓN DEL ASEGURADO
# 26894                 99.0           traspaso a otro agente
# 26908                 99.0  intervencion de la comopetencia
# 26934                  8.0         LA HA HECHO CON EL BANCO
#
# [1019 rows x 2 columns]>
# c2 <bound method DataFrame.count of        POL_MotivoAnulacion          POL_DescripcionMotivo
# 0                     99.0               TRACTOR AVERIADO
# ...

# %%
print("c3",otros3.count)
print("c4",otros4.count)
# Out:
# c3 <bound method DataFrame.count of                     POL_DescripcionMotivo
# 0                      Peticion asegurado
# 4             ANULADO POR CIA CTA 09/2001
# 9                        CESE DEL NEGOCIO
# 12          POLIZA YA ANULADA CON EXTORNO
# 17      P.O. ASEGURADO HA VENDIDO LA MOTO
# ...                                   ...
# 428787                              Error
# 428793     pertenece al colectivo banco m
# 428989                             Impago
# 429151                  Póliza duplicada.
# 429171                   Se ha descargado
#
# [147392 rows x 1 columns]>
# c4 <bound method DataFrame.count of                  POL_DescripcionMotivo
# 13               Canvi prenedor/c.8643
# 25     Canvi Prenedor: Josep Corominas
# 28                     FETA A CATALANA
# 29           NINGUNO DE LOS ANTERIORES
# 30                      canvi corredor
# ...                                ...
# 46843                Acuerdo anulación
# 46848                 Extinción Riesgo
# ...

# %%
print("c5",otros5.count)
print("c6",otros6.count)
# Out:
# c5 <bound method DataFrame.count of                     POL_DescripcionMotivo
# 16              Ninguno de los anteriores
# 29                       Extinción Riesgo
# 31                      Acuerdo anulación
# 40                      Acuerdo anulación
# 46                       Extinción Riesgo
# ...                                   ...
# 26144                   Acuerdo anulación
# 26171      Erro informatico, zona ajardin
# 26192  SOLICITUD ASEGURADO (OTRAS CAUSAS)
# 26196  SOLICITUD ASEGURADO (OTRAS CAUSAS)
# 26197  SOLICITUD ASEGURADO (OTRAS CAUSAS)
#
# [342 rows x 1 columns]>
# c6 <bound method DataFrame.count of                          POL_DescripcionMotivo
# 2                                    AVARIA VH
# 4                               BAIXA WEB CIA.
# 9       BAIXA FORA DE PLAÇ CLIENT ENVIA ESCRIT
# 14              CON EXTORNO X NB 3021000052187
# 24                                  ORDRE CLTE
# ...                                        ...
# ...

# %%
print("c7",otros7.count)
print("c8",otros8.count)
# Out:
# c7 <bound method DataFrame.count of                             POL_DescripcionMotivo
# 34                                    CANVI AGENT
# 97     DEPSA DONA DE BAIXA PER ASNEF DE L´INQUILI
# 102                                 FALLECIMIENTO
# 108                              POLISSA EXPIRADA
# 115                                CANVI PRENEDOR
# ...                                           ...
# 23887                         Falta Documentación
# 23889                                      Impago
# 23894                            Extinción Riesgo
# 23905                                      Impago
# 23955                               ERROR EMISSIO
#
# [2009 rows x 1 columns]>
# c8 <bound method DataFrame.count of                        POL_DescripcionMotivo
# 3       CLIENTE CONSIDERA QUE NO LO NECESITA
# 8                          REEMPLAZO ALLIANZ
# 14                               REEMP A AXA
# 20                                  46186182
# ...

# %%
print("c9",otros9.count)
# Out:
# c9 <bound method DataFrame.count of                      POL_DescripcionMotivo
# 0       CLIENTE ENTRAGA CARTA DE ANULACION
# 1                      ANUL.ASEG.POR CARTA
# 7                      ERROR EN LA EMISION
# 9              CLIENTE ENVIA FAX ANULACION
# 12                             COMPETENCIA
# ...                                    ...
# 196700             CORREO JVIDAL ANULACION
# 196705                  CONTRATA CON BANCO
# 196711                         VENDERA VEH
# 196718                             WEB CIA
# 196732                   NO EXPRESA MOTIVO
#
# [62322 rows x 1 columns]>

# %%
otros1.info
# Out:
# <bound method DataFrame.info of                  POL_DescripcionMotivo
# 100           TOMADOR CAMBIA DE AGENTE
# 809            desaparicion del riesgo
# 975         RESCATE TOTAL DE LA POLIZA
# 1485           desaparicion del riesgo
# 1828            A PETICION DEL CLIENTE
# ...                                ...
# 26788               PETICION ASEGURADO
# 26824   ASEGURADO SOLICITA POR WHATSAP
# 26881         A PETICIÓN DEL ASEGURADO
# 26894           traspaso a otro agente
# 26908  intervencion de la comopetencia
#
# [298 rows x 1 columns]>

# %%
clean_databases=pd.concat([otros1, otros2, otros3, otros4, otros5, otros6, otros7, otros8, otros9], ignore_index=True)
clean_databases['POL_DescripcionMotivo'].map(lambda x: re.sub('[,\.!?_]', '', x))
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue').generate(str(clean_databases['POL_DescripcionMotivo']))
#wordcloud.generate(otros1)
# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x20C25ABF940>

# %%
test=polizas9.loc[
   # polizas.POL_FechaAnulacion.notnull()
     (polizas9.POL_MotivoAnulacion == 0)&
     (polizas9.POL_DescripcionMotivo.notnull())
    & (polizas9.POL_DescripcionMotivo != "* Anulación automática"),
    [
       
        "POL_MotivoAnulacion", "POL_DescripcionMotivo",
    ],
]
print(test)
# Out:
#         POL_MotivoAnulacion                        POL_DescripcionMotivo
# 39385                   0.0                             CIA.ANULA POLIZA
# 59284                   0.0            CLIENTE ENVIA E-MAIL DE ANULACION
# 69969                   0.0                             CIA.ANULA POLIZA
# 72324                   0.0                             CIA.ANULA POLIZA
# 77535                   0.0                             CIA.ANULA POLIZA
# 80505                   0.0                             CIA.ANULA POLIZA
# 85767                   0.0                             CIA.ANULA POLIZA
# 87085                   0.0                             CIA.ANULA POLIZA
# 88494                   0.0                             CIA.ANULA POLIZA
# 88866                   0.0                             CIA.ANULA POLIZA
# 88880                   0.0                             CIA.ANULA POLIZA
# 90213                   0.0                             CIA.ANULA POLIZA
# ...

# %%
clean_databases2=pd.concat([polizas1, polizas2, polizas3, polizas4, polizas5, polizas6, polizas7, polizas8, polizas9], ignore_index=True)
grouped_by_id=clean_databases2['POL_MotivoAnulacion'].value_counts()
aux=grouped_by_id.sort_index(axis = 0).values.reshape(1,-1)
aux
#data=pd.DataFrame([aux]).values.reshape(-1,1)
#print(aux)
#data
#grouped_by_id
#clean_databases['count'] = clean_databases.groupby('POL_MotivoAnulacion')['POL_MotivoAnulacion'].transform('count')
#clean_databases['No'] = clean_databases.groupby('POL_MotivoAnulacion')['POL_MotivoAnulacion'].cumcount() + 1
#clean_databases.head(30)
# Out:
# array([[141346,  26510,   9695,  62840,   4956,  58097,  48449,  51671,
#          55639,   1352,  39271,   9421,   3796,   1177,   1669,  10851,
#           8408,    759,      6,   4141,    543,   5200,     85,     49,
#          15640,    998,  20763,  15801,   9013,    622,    606,    377,
#            537,    165,    208,    325,   2479,    313,    161,     67,
#              5,    133,     54,      7,    296,    649,   1161,    147,
#            170,     10,    110,     39,  16564,     39,   4813,      9,
#              3,      2,      1,     46,      1,     17,      1,     21,
#              1,      1,     31,     37,      2,      9,      1,     30,
#              1, 230350,  15520,  32442,   1127,   2965,   1115,   1022,
#            111,    918,    426,    187,      4,      7,      1,      7,
#              1,      5,      1,      4,     26,    100,    412,     12,
#              2,      8,      1,     35,      4,     42,    945,   1150,
# ...

# %%
plt.hist(grouped_by_id)
plt.figure(figsize=(250,1))
plt.tight_layout()

# %%
clean_databases2['POL_MotivoAnulacion'].value_counts()[:20].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
c1_Mot1=polizas1.loc[
   # polizas.POL_FechaAnulacion.notnull()
      ((polizas1.POL_MotivoAnulacion == 1) |
      (polizas1.POL_MotivoAnulacion == 2) |
      (polizas1.POL_MotivoAnulacion == 3) |
      (polizas1.POL_MotivoAnulacion == 4) |
      (polizas1.POL_MotivoAnulacion == 5) |
      (polizas1.POL_MotivoAnulacion == 6) |
      (polizas1.POL_MotivoAnulacion == 7) |
      (polizas1.POL_MotivoAnulacion == 8) |
      (polizas1.POL_MotivoAnulacion == 9) |
      (polizas1.POL_MotivoAnulacion == 10) |
      (polizas1.POL_MotivoAnulacion == 11) |
      (polizas1.POL_MotivoAnulacion == 12) |
      (polizas1.POL_MotivoAnulacion == 13) |
      (polizas1.POL_MotivoAnulacion == 17) |
      (polizas1.POL_MotivoAnulacion == 20) |
      (polizas1.POL_MotivoAnulacion == 25) )&
      (polizas1.POL_DescripcionMotivo.notnull())
      & (polizas1.POL_DescripcionMotivo != "* Anulación automática"),
    [
       
       "POL_MotivoAnulacion", "POL_DescripcionMotivo",
    ],
]
c2_Mot1=polizas2.loc[
   # polizas.POL_FechaAnulacion.notnull()
      ((polizas2.POL_MotivoAnulacion == 1) |
      (polizas2.POL_MotivoAnulacion == 2) |
      (polizas2.POL_MotivoAnulacion == 3) |
      (polizas2.POL_MotivoAnulacion == 4) |
      (polizas2.POL_MotivoAnulacion == 5) |
      (polizas2.POL_MotivoAnulacion == 6) |
      (polizas2.POL_MotivoAnulacion == 7) |
      (polizas2.POL_MotivoAnulacion == 8) |
      (polizas2.POL_MotivoAnulacion == 9) |
      (polizas2.POL_MotivoAnulacion == 10) |
      (polizas2.POL_MotivoAnulacion == 11) |
      (polizas2.POL_MotivoAnulacion == 12) |
      (polizas2.POL_MotivoAnulacion == 13) |
      (polizas2.POL_MotivoAnulacion == 17) |
      (polizas2.POL_MotivoAnulacion == 20) |
      (polizas2.POL_MotivoAnulacion == 25)) &
      (polizas2.POL_DescripcionMotivo.notnull())
      & (polizas2.POL_DescripcionMotivo != "* Anulación automática"),
    [
       
       "POL_MotivoAnulacion", "POL_DescripcionMotivo",
    ],
]
c3_Mot1=polizas3.loc[
   # polizas.POL_FechaAnulacion.notnull()
      ((polizas3.POL_MotivoAnulacion == 1) |
      (polizas3.POL_MotivoAnulacion == 2) |
      (polizas3.POL_MotivoAnulacion == 3) |
      (polizas3.POL_MotivoAnulacion == 4) |
      (polizas3.POL_MotivoAnulacion == 5) |
      (polizas3.POL_MotivoAnulacion == 6) |
      (polizas3.POL_MotivoAnulacion == 7) |
      (polizas3.POL_MotivoAnulacion == 8) |
      (polizas3.POL_MotivoAnulacion == 9) |
      (polizas3.POL_MotivoAnulacion == 10) |
      (polizas3.POL_MotivoAnulacion == 11) |
      (polizas3.POL_MotivoAnulacion == 12) |
      (polizas3.POL_MotivoAnulacion == 13) |
      (polizas3.POL_MotivoAnulacion == 17) |
      (polizas3.POL_MotivoAnulacion == 20) |
      (polizas3.POL_MotivoAnulacion == 25))&
      (polizas3.POL_DescripcionMotivo.notnull())
      & (polizas3.POL_DescripcionMotivo != "* Anulación automática"),
    [
       
       "POL_MotivoAnulacion", "POL_DescripcionMotivo",
    ],
]
c4_Mot1=polizas4.loc[
   # polizas.POL_FechaAnulacion.notnull()
      ((polizas4.POL_MotivoAnulacion == 1) |
      (polizas4.POL_MotivoAnulacion == 2) |
      (polizas4.POL_MotivoAnulacion == 3) |
      (polizas4.POL_MotivoAnulacion == 4) |
      (polizas4.POL_MotivoAnulacion == 5) |
      (polizas4.POL_MotivoAnulacion == 6) |
      (polizas4.POL_MotivoAnulacion == 7) |
      (polizas4.POL_MotivoAnulacion == 8) |
      (polizas4.POL_MotivoAnulacion == 9) |
      (polizas4.POL_MotivoAnulacion == 10) |
      (polizas4.POL_MotivoAnulacion == 11) |
      (polizas4.POL_MotivoAnulacion == 12) |
      (polizas4.POL_MotivoAnulacion == 13) |
      (polizas4.POL_MotivoAnulacion == 17) |
      (polizas4.POL_MotivoAnulacion == 20) |
      (polizas4.POL_MotivoAnulacion == 25) )&
      (polizas4.POL_DescripcionMotivo.notnull())
      & (polizas4.POL_DescripcionMotivo != "* Anulación automática"),
    [
       
       "POL_MotivoAnulacion", "POL_DescripcionMotivo",
    ],
]

c5_Mot1=polizas5.loc[
   # polizas.POL_FechaAnulacion.notnull()
      ((polizas5.POL_MotivoAnulacion == 1) |
      (polizas5.POL_MotivoAnulacion == 2) |
      (polizas5.POL_MotivoAnulacion == 3) |
      (polizas5.POL_MotivoAnulacion == 4) |
      (polizas5.POL_MotivoAnulacion == 5) |
      (polizas5.POL_MotivoAnulacion == 6) |
      (polizas5.POL_MotivoAnulacion == 7) |
      (polizas5.POL_MotivoAnulacion == 8) |
      (polizas5.POL_MotivoAnulacion == 9) |
      (polizas5.POL_MotivoAnulacion == 10) |
      (polizas5.POL_MotivoAnulacion == 11) |
      (polizas5.POL_MotivoAnulacion == 12) |
      (polizas5.POL_MotivoAnulacion == 13) |
      (polizas5.POL_MotivoAnulacion == 17) |
      (polizas5.POL_MotivoAnulacion == 20) |
      (polizas5.POL_MotivoAnulacion == 25) )&
      (polizas5.POL_DescripcionMotivo.notnull())
      & (polizas5.POL_DescripcionMotivo != "* Anulación automática"),
    [
       
       "POL_MotivoAnulacion", "POL_DescripcionMotivo",
    ],
]
c6_Mot1=polizas6.loc[
   # polizas.POL_FechaAnulacion.notnull()
      ((polizas6.POL_MotivoAnulacion == 1) |
      (polizas6.POL_MotivoAnulacion == 2) |
      (polizas6.POL_MotivoAnulacion == 3) |
      (polizas6.POL_MotivoAnulacion == 4) |
      (polizas6.POL_MotivoAnulacion == 5) |
      (polizas6.POL_MotivoAnulacion == 6) |
      (polizas6.POL_MotivoAnulacion == 7) |
      (polizas6.POL_MotivoAnulacion == 8) |
      (polizas6.POL_MotivoAnulacion == 9) |
      (polizas6.POL_MotivoAnulacion == 10) |
      (polizas6.POL_MotivoAnulacion == 11) |
      (polizas6.POL_MotivoAnulacion == 12) |
      (polizas6.POL_MotivoAnulacion == 13) |
      (polizas6.POL_MotivoAnulacion == 17) |
      (polizas6.POL_MotivoAnulacion == 20) |
      (polizas6.POL_MotivoAnulacion == 25)  )&
      (polizas6.POL_DescripcionMotivo.notnull())
      & (polizas6.POL_DescripcionMotivo != "* Anulación automática"),
    [
       
       "POL_MotivoAnulacion", "POL_DescripcionMotivo",
    ],
]

c7_Mot1=polizas7.loc[
   # polizas.POL_FechaAnulacion.notnull()
      ((polizas7.POL_MotivoAnulacion == 1) |
      (polizas7.POL_MotivoAnulacion == 2) |
      (polizas7.POL_MotivoAnulacion == 3) |
      (polizas7.POL_MotivoAnulacion == 4) |
      (polizas7.POL_MotivoAnulacion == 5) |
      (polizas7.POL_MotivoAnulacion == 6) |
      (polizas7.POL_MotivoAnulacion == 7) |
      (polizas7.POL_MotivoAnulacion == 8) |
      (polizas7.POL_MotivoAnulacion == 9) |
      (polizas7.POL_MotivoAnulacion == 10) |
      (polizas7.POL_MotivoAnulacion == 11) |
      (polizas7.POL_MotivoAnulacion == 12) |
      (polizas7.POL_MotivoAnulacion == 13) |
      (polizas7.POL_MotivoAnulacion == 17) |
      (polizas7.POL_MotivoAnulacion == 20) |
      (polizas7.POL_MotivoAnulacion == 25)  )&
      (polizas7.POL_DescripcionMotivo.notnull())
      & (polizas7.POL_DescripcionMotivo != "* Anulación automática"),
    [
       
       "POL_MotivoAnulacion", "POL_DescripcionMotivo",
    ],
]
c8_Mot1=polizas8.loc[
   # polizas.POL_FechaAnulacion.notnull()
      ((polizas8.POL_MotivoAnulacion == 1) |
      (polizas8.POL_MotivoAnulacion == 2) |
      (polizas8.POL_MotivoAnulacion == 3) |
      (polizas8.POL_MotivoAnulacion == 4) |
      (polizas8.POL_MotivoAnulacion == 5) |
      (polizas8.POL_MotivoAnulacion == 6) |
      (polizas8.POL_MotivoAnulacion == 7) |
      (polizas8.POL_MotivoAnulacion == 8) |
      (polizas8.POL_MotivoAnulacion == 9) |
      (polizas8.POL_MotivoAnulacion == 10) |
      (polizas8.POL_MotivoAnulacion == 11) |
      (polizas8.POL_MotivoAnulacion == 12) |
      (polizas8.POL_MotivoAnulacion == 13) |
      (polizas8.POL_MotivoAnulacion == 17) |
      (polizas8.POL_MotivoAnulacion == 20) |
      (polizas8.POL_MotivoAnulacion == 25) )&
      (polizas8.POL_DescripcionMotivo.notnull())
      & (polizas8.POL_DescripcionMotivo != "* Anulación automática"),
    [
       
       "POL_MotivoAnulacion", "POL_DescripcionMotivo",
    ],
]

c9_Mot1=polizas9.loc[
   # polizas.POL_FechaAnulacion.notnull()
      ((polizas9.POL_MotivoAnulacion == 1) |
      (polizas9.POL_MotivoAnulacion == 2) |
      (polizas9.POL_MotivoAnulacion == 3) |
      (polizas9.POL_MotivoAnulacion == 4) |
      (polizas9.POL_MotivoAnulacion == 5) |
      (polizas9.POL_MotivoAnulacion == 6) |
      (polizas9.POL_MotivoAnulacion == 7) |
      (polizas9.POL_MotivoAnulacion == 8) |
      (polizas9.POL_MotivoAnulacion == 9) |
      (polizas9.POL_MotivoAnulacion == 10) |
      (polizas9.POL_MotivoAnulacion == 11) |
      (polizas9.POL_MotivoAnulacion == 12) |
      (polizas9.POL_MotivoAnulacion == 13) |
      (polizas9.POL_MotivoAnulacion == 17) |
      (polizas9.POL_MotivoAnulacion == 20) |
      (polizas9.POL_MotivoAnulacion == 25) )&
      (polizas9.POL_DescripcionMotivo.notnull())
      & (polizas9.POL_DescripcionMotivo != "* Anulación automática"),
    [
       
       "POL_MotivoAnulacion", "POL_DescripcionMotivo",
    ],
]
clean_databases=pd.concat([ c1_Mot1,c2_Mot1,c3_Mot1,c4_Mot1, c5_Mot1, c6_Mot1, c7_Mot1, c8_Mot1, c9_Mot1 ], ignore_index=True)
clean_databases['POL_DescripcionMotivo']=clean_databases['POL_DescripcionMotivo'].apply(str)
clean_databases['POL_DescripcionMotivo'].map(lambda x: re.sub('[,\.!?_]', '', x))
# Out:
# 0                                   pol 8140800029032
# 1                     Impago: NO RENUEVA (POR PRECIO)
# 2                                           REEMPLAZO
# 3         Ninguno: SOLICITUD ASEGURADO (OTRAS CAUSAS)
# 4                                    camibo a Allianz
#                              ...
# 143919                        CORREO JVIDAL ANULACION
# 143920                             CONTRATA CON BANCO
# 143921                                    VENDERA VEH
# 143922                                        WEB CIA
# 143923                              NO EXPRESA MOTIVO
# Name: POL_DescripcionMotivo, Length: 143924, dtype: object

# %%
clean_databases['POL_MotivoAnulacion'].value_counts()[:20].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
clean_databases.head(15)
pd.DataFrame(clean_databases).to_csv('todos.csv', index=False)

# %%
motanulacionpol1 = pd.read_csv("c1_MotAnulacionPol.csv")
motanulacionpol1.loc[:, ["MAP_Id", "MAP_Descripcion"]]
# Out:
#     MAP_Id                   MAP_Descripcion
# 0        1       Falta de pago. Reclamación.
# 1        2               Error en la emisión
# 2        3       Falta de pago. Insolvencia.
# 3        4            Falta de formalización
# 4        5                         Reemplazo
# 5        6                          Traspaso
# 6        7           Cese o venta del riesgo
# 7        8     Anulación asegurado por carta
# 8        9              Ilocalizable tomador
# 9       10               Fin riesgo.Temporal
# 10      11                    Siniestralidad
# 11      12           Desaparición del riesgo
# 12      13                Convenio anulación
# 13      99                             Otros
# 14     100              AUXILIAR INDICA BAJA
# 15     101                  Cambio de agente
# 16     102                 Decisión compañía
# 17     103  Anulación asegurado por teléfono

# %%
motanulacionpol2 = pd.read_csv("c2_MotAnulacionPol.csv")
motanulacionpol2.loc[:, ["MAP_Id", "MAP_Descripcion"]]
# Out:
#     MAP_Id                MAP_Descripcion
# 0        1    Falta de pago. Reclamación.
# 1        2            Error en la emisión
# 2        3    Falta de pago. Insolvencia.
# 3        4         Falta de formalización
# 4        5                      Reemplazo
# 5        6                       Traspaso
# 6        7        Cese o venta del riesgo
# 7        8  Anulación asegurado por carta
# 8        9           Ilocalizable tomador
# 9       10            Fin riesgo.Temporal
# 10      11                 Siniestralidad
# 11      12        Desaparición del riesgo
# 12      13             Convenio anulación
# 13      99                          Otros
# 14     100                    Competencia

# %%
motanulacionpol3 = pd.read_csv("c3_MotAnulacionPol.csv")
motanulacionpol3.loc[:, ["MAP_Id", "MAP_Descripcion"]]
# Out:
#     MAP_Id                          MAP_Descripcion
# 0        0
# 1        1              Falta de pago. Reclamación.
# 2        2                      Error en la emisión
# 3        3              Falta de pago. Insolvencia.
# 4        4                   Falta de formalización
# 5        5                                Reemplazo
# 6        6                                 Traspaso
# 7        7                  Cese o venta del riesgo
# 8        8            Anulación asegurado por carta
# 9        9                     Ilocalizable tomador
# 10      10                      Fin riesgo.Temporal
# 11      11                           Siniestralidad
# 12      12                  Desaparición del riesgo
# 13      13                       Convenio anulación
# 14      15                    Traspaso a Servicover
# 15      16                          Por Competencia
# 16      17                       Cambio de Mediador
# 17      99                                    Otros
# ...

# %%
motanulacionpol4 = pd.read_csv("c4_MotAnulacionPol.csv")
motanulacionpol4.loc[:, ["MAP_Id", "MAP_Descripcion"]].head(20)
# Out:
#     MAP_Id                MAP_Descripcion
# 0        1    Falta de pago. Reclamación.
# 1        2            Error en la emisión
# 2        3    Falta de pago. Insolvencia.
# 3        4         Falta de formalización
# 4        5                      Reemplazo
# 5        6                       Traspaso
# 6        7        Cese o venta del riesgo
# 7        8  Anulación asegurado por carta
# 8        9           Ilocalizable tomador
# 9       10            Fin riesgo.Temporal
# 10      11                 Siniestralidad
# 11      12        Desaparición del riesgo
# 12      13             Convenio anulación
# 13      17                Baja no circula
# 14      18                  Cambio riesgo
# 15      20                    Competencia
# 16      21                       Desguace
# 17      23     Emisión  errónea de recibo
# 18      25                   Venta riesgo
# 19      26            Desaparición riesgo

# %%
motanulacionpol5 = pd.read_csv("c5_MotAnulacionPol.csv")
motanulacionpol5.loc[:, ["MAP_Id", "MAP_Descripcion"]]
# Out:
#     MAP_Id                        MAP_Descripcion
# 0        1            Falta de pago. Reclamación.
# 1        2                    Error en la emisión
# 2        3            Falta de pago. Insolvencia.
# 3        4                 Falta de formalización
# 4        5                              Reemplazo
# 5        6                               Traspaso
# 6        7                Cese o venta del riesgo
# 7        8          Anulación asegurado por carta
# 8        9                   Ilocalizable tomador
# 9       10                    Fin riesgo.Temporal
# 10      11                         Siniestralidad
# 11      12                Desaparición del riesgo
# 12      13                     Convenio anulación
# 13      15                     Códigos Devolución
# 14      17                 A.P. - Baja no circula
# 15      18                   A.P. - Cambio riesgo
# 16      19              A.P. - Cambio vencimiento
# 17      20                     A.P. - Competencia
# ...

# %%
motanulacionpol6 = pd.read_csv("c6_MotAnulacionPol.csv")
motanulacionpol6.loc[:, ["MAP_Id", "MAP_Descripcion"]]
# Out:
#     MAP_Id                        MAP_Descripcion
# 0        1            Falta de pago. Reclamación.
# 1        2                          ERROR EMISION
# 2        3            Falta de pago. Insolvencia.
# 3        4                 Falta de formalización
# 4        5                   REEMPLAZO - TRASPASO
# 5        6                               Traspaso
# 6        7                Cese o venta del riesgo
# 7        8          Anulación asegurado por carta
# 8        9                   Ilocalizable tomador
# 9       10                    Fin riesgo.Temporal
# 10      11                         Siniestralidad
# 11      12                Desaparición del riesgo
# 12      13                     Convenio anulación
# 13      15                     Códigos Devolución
# 14      16                  Baja directa compañía
# 15      17                        Baja no circula
# 16      18                          Cambio riesgo
# 17      19                     Cambio vencimiento
# ...

# %%
motanulacionpol7 = pd.read_csv("c7_MotAnulacionPol.csv")
motanulacionpol7.loc[:, ["MAP_Id", "MAP_Descripcion"]]
# Out:
#     MAP_Id                MAP_Descripcion
# 0        1    Falta de pago. Reclamación.
# 1        2            Error en la emisión
# 2        3    Falta de pago. Insolvencia.
# 3        4         Falta de formalización
# 4        5                      Reemplazo
# 5        6                       Traspaso
# 6        7        Cese o venta del riesgo
# 7        8  Anulación asegurado por carta
# 8        9           Ilocalizable tomador
# 9       10            Fin riesgo.Temporal
# 10      11                 Siniestralidad
# 11      12        Desaparición del riesgo
# 12      13             Convenio anulación
# 13      15             Códigos Devolución
# 14      16          Baja directa compañía
# 15      17                Baja no circula
# 16      18                  Cambio riesgo
# 17      19             Cambio vencimiento
# 18      20                    Competencia
# 19      21                       Desguace
# 20      22                   Nueva póliza
# ...

# %%
motanulacionpol8 = pd.read_csv("c8_MotAnulacionPol.csv")
motanulacionpol8.loc[:, ["MAP_Id", "MAP_Descripcion"]]
# Out:
#     MAP_Id                   MAP_Descripcion
# 0        1       Falta de pago. Reclamación.
# 1        2               Error en la emisión
# 2        3       Falta de pago. Insolvencia.
# 3        4            Falta de formalización
# 4        5                         Reemplazo
# 5        6                          Traspaso
# 6        7           Cese o venta del riesgo
# 7        8     Anulación asegurado por carta
# 8        9              Ilocalizable tomador
# 9       10               Fin riesgo.Temporal
# 10      11                    Siniestralidad
# 11      12           Desaparición del riesgo
# 12      13                Convenio anulación
# 13      99                             Otros
# 14     100              AUXILIAR INDICA BAJA
# 15     101                  Cambio de agente
# 16     102                 Decisión compañía
# 17     103  Anulación asegurado por teléfono

# %%
motanulacionpol9 = pd.read_csv("c9_MotAnulacionPol.csv")
motanulacionpol9.loc[:, ["MAP_Id", "MAP_Descripcion"]]
# Out:
#     MAP_Id                MAP_Descripcion
# 0        1    Falta de pago. Reclamación.
# 1        2            Error en la emisión
# 2        3    Falta de pago. Insolvencia.
# 3        4         Falta de formalización
# 4        5                      Reemplazo
# 5        6                       Traspaso
# 6        7        Cese o venta del riesgo
# 7        8  Anulación asegurado por carta
# 8        9           Ilocalizable tomador
# 9       10            Fin riesgo.Temporal
# 10      11                 Siniestralidad
# 11      12        Desaparición del riesgo
# 12      13             Convenio anulación
# 13      99                          Otros
# 14     100                    Competencia
